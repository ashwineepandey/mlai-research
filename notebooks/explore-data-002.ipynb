# %%
import rasterio
import rasterio.plot
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
# load shp file
rasterimg1 = rasterio.open("../data/01_base/dsm_28cm/dsm_aoi_1.tif") # import tif using rasterio
rasterimg2 = rasterio.open("../data/01_base/dsm_7cm_resampled/dsm_aoi_1.tif") # import tif using rasterio

# %%
rasterimg1.count, rasterimg1.width, rasterimg1.height # (1, 4000, 4000)
# Out:
# (1, 5594, 5866)

# %%
rasterimg2.count, rasterimg2.width, rasterimg2.height # (1, 1000, 1000)
# Out:
# (1, 22377, 23466)

# %%
fig, ax = plt.subplots(figsize = (20,20))
rasterio.plot.show(rasterimg1, ax=ax)
plt.show()

# %%
fig, ax = plt.subplots(figsize = (20,20))
rasterio.plot.show(rasterimg2, ax=ax)
plt.show()
